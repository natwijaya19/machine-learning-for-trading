# %% [markdown]
# # Data Access with Zipline

# %% [markdown]
# Zipline is the algorithmic trading library that used to power the now-defunct Quantopian backtesting and live-trading platform. It is also available offline to develop a strategy using a limited number of free data bundles that can be ingested and used to test the performance of trading ideas.

# %% [markdown]
# ## Zipline installation

# %% [markdown]
# > This notebook requires the `conda` environment `backtest`. Please see the [installation instructions](../installation/README.md) for running the latest Docker image or alternative ways to set up your environment.

# %% [markdown]
# There is much more information about Zipline in [Chapter 8](../../08_ml4t_workflow/04_ml4t_workflow_with_zipline).

# %% [markdown]
# ## Imports & Settings

# %%
# %matplotlib inline
import pandas as pd

# %%
# %load_ext zipline

# %% [markdown]
# ## zipline Demo

# %% [markdown]
# ### Ingest Data

# %% [markdown]
# Get QUANDL API key and follow instructions to download zipline bundles [here](https://zipline.ml4trading.io/bundles.html). This boils down to running:

# %%
# !zipline ingest

# %% [markdown]
# See `zipline` [docs](https://zipline.ml4trading.io/bundles.html) on the download and management of data bundles used to simulate backtests.
#
# The following commandline instruction lists the available bundles (store per default in `~/.zipline`.

# %%
# !zipline bundles

# %% [markdown]
# ### Data access using zipline

# %% [markdown]
# The following code illustrates how zipline permits us to access daily stock data for a range of companies. You can run zipline scripts in the Jupyter Notebook using the magic function of the same name.

# %% [markdown]
# First, you need to initialize the context with the desired security symbols. We'll also use a counter variable. Then zipline calls handle_data, where we use the `data.history()` method to look back a single period and append the data for the last day to a .csv file:

# %%
# %%zipline --start 2010-1-1 --end 2018-1-1 --data-frequency daily --no-benchmark
# from zipline.api import order_target, record, symbol
# import pandas as pd
#
# def initialize(context):
#     context.i = 0
#     context.assets = [symbol('META'), symbol('GOOG'), symbol('AMZN')]
#
# def handle_data(context, data):
#     df = data.history(context.assets, fields=['price', 'volume'], bar_count=1, frequency="1d")
#     df = df.reset_index()
#
#     if context.i == 0:
#         df.columns = ['date', 'asset', 'price', 'volume']
#         df.to_csv('stock_data.csv', index=False)
#     else:
#         df.to_csv('stock_data.csv', index=False, mode='a', header=None)
#     context.i += 1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\zipline\data\bundles\core.py:488, in _make_bundle_core.<locals>.most_recent_data(bundle_name, timestamp, environ)
#     487 try:
# --> 488     candidates = os.listdir(
#     489         pth.data_path([bundle_name], environ=environ),
#     490     )
#     491     return pth.data_path(
#     492         [
#     493             bundle_name,
#    (...)
#     499         environ=environ,
#     500     )
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\kikim\\.zipline\\data\\quandl'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 get_ipython().run_cell_magic('zipline', '--start 2010-1-1 --end 2018-1-1 --data-frequency daily --no-benchmark', 'from zipline.api import order_target, record, symbol\nimport pandas as pd\n\ndef initialize(context):\n    context.i = 0\n    context.assets = [symbol(\'META\'), symbol(\'GOOG\'), symbol(\'AMZN\')]\n    \ndef handle_data(context, data):\n    df = data.history(context.assets, fields=[\'price\', \'volume\'], bar_count=1, frequency="1d")\n    df = df.reset_index()\n    \n    if context.i == 0:\n        df.columns = [\'date\', \'asset\', \'price\', \'volume\']\n        df.to_csv(\'stock_data.csv\', index=False)\n    else:\n        df.to_csv(\'stock_data.csv\', index=False, mode=\'a\', header=None)\n    context.i += 1\n')
#
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\IPython\core\interactiveshell.py:2478, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2476 with self.builtin_trap:
#    2477     args = (magic_arg_s, cell)
# -> 2478     result = fn(*args, **kwargs)
#    2480 # The code below prevents the output from being displayed
#    2481 # when using magics with decodator @output_can_be_silenced
#    2482 # when the last Python token in the expression is a ';'.
#    2483 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\zipline\__main__.py:341, in zipline_magic(line, cell)
#     334 load_extensions(
#     335     default=True,
#     336     extensions=[],
#     337     strict=True,
#     338     environ=os.environ,
#     339 )
#     340 try:
# --> 341     return run.main(
#     342         # put our overrides at the start of the parameter list so that
#     343         # users may pass values with higher precedence
#     344         [
#     345             "--algotext",
#     346             cell,
#     347             "--output",
#     348             os.devnull,  # don't write the results by default
#     349         ]
#     350         + (
#     351             [
#     352                 # these options are set when running in line magic mode
#     353                 # set a non None algo text to use the ipython user_ns
#     354                 "--algotext",
#     355                 "",
#     356                 "--local-namespace",
#     357             ]
#     358             if cell is None
#     359             else []
#     360         )
#     361         + line.split(),
#     362         "%s%%zipline" % ((cell or "") and "%"),
#     363         # don't use system exit and propogate errors to the caller
#     364         standalone_mode=False,
#     365     )
#     366 except SystemExit as exc:
#     367     # https://github.com/mitsuhiko/click/pull/533
#     368     # even in standalone_mode=False `--help` really wants to kill us ;_;
#     369     if exc.code:
#
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\click\core.py:1078, in BaseCommand.main(self, args, prog_name, complete_var, standalone_mode, windows_expand_args, **extra)
#    1076 try:
#    1077     with self.make_context(prog_name, args, **extra) as ctx:
# -> 1078         rv = self.invoke(ctx)
#    1079         if not standalone_mode:
#    1080             return rv
#
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\click\core.py:1434, in Command.invoke(self, ctx)
#    1431     echo(style(message, fg="red"), err=True)
#    1433 if self.callback is not None:
# -> 1434     return ctx.invoke(self.callback, **ctx.params)
#
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\click\core.py:783, in Context.invoke(_Context__self, _Context__callback, *args, **kwargs)
#     781 with augment_usage_errors(__self):
#     782     with ctx:
# --> 783         return __callback(*args, **kwargs)
#
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\click\decorators.py:33, in pass_context.<locals>.new_func(*args, **kwargs)
#      32 def new_func(*args: "P.args", **kwargs: "P.kwargs") -> "R":
# ---> 33     return f(get_current_context(), *args, **kwargs)
#
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\zipline\__main__.py:306, in run(ctx, algofile, algotext, define, data_frequency, capital_base, bundle, bundle_timestamp, benchmark_file, benchmark_symbol, benchmark_sid, no_benchmark, start, end, output, trading_calendar, print_algo, metrics_set, local_namespace, blotter)
#     297 trading_calendar = get_calendar(trading_calendar)
#     299 benchmark_spec = BenchmarkSpec.from_cli_params(
#     300     no_benchmark=no_benchmark,
#     301     benchmark_sid=benchmark_sid,
#     302     benchmark_symbol=benchmark_symbol,
#     303     benchmark_file=benchmark_file,
#     304 )
# --> 306 return _run(
#     307     initialize=None,
#     308     handle_data=None,
#     309     before_trading_start=None,
#     310     analyze=None,
#     311     algofile=algofile,
#     312     algotext=algotext,
#     313     defines=define,
#     314     data_frequency=data_frequency,
#     315     capital_base=capital_base,
#     316     bundle=bundle,
#     317     bundle_timestamp=bundle_timestamp,
#     318     start=start,
#     319     end=end,
#     320     output=output,
#     321     trading_calendar=trading_calendar,
#     322     print_algo=print_algo,
#     323     metrics_set=metrics_set,
#     324     local_namespace=local_namespace,
#     325     environ=os.environ,
#     326     blotter=blotter,
#     327     benchmark_spec=benchmark_spec,
#     328     custom_loader=None,
#     329 )
#
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\zipline\utils\run_algo.py:93, in _run(handle_data, initialize, before_trading_start, analyze, algofile, algotext, defines, data_frequency, capital_base, bundle, bundle_timestamp, start, end, output, trading_calendar, print_algo, metrics_set, local_namespace, environ, blotter, custom_loader, benchmark_spec)
#      64 def _run(
#      65     handle_data,
#      66     initialize,
#    (...)
#      86     benchmark_spec,
#      87 ):
#      88     """Run a backtest for the given algorithm.
#      89
#      90     This is shared between the cli and :func:`zipline.run_algo`.
#      91     """
# ---> 93     bundle_data = bundles.load(
#      94         bundle,
#      95         environ,
#      96         bundle_timestamp,
#      97     )
#      99     if trading_calendar is None:
#     100         trading_calendar = get_calendar("XNYS")
#
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\zipline\data\bundles\core.py:532, in _make_bundle_core.<locals>.load(name, environ, timestamp)
#     530 if timestamp is None:
#     531     timestamp = pd.Timestamp.utcnow()
# --> 532 timestr = most_recent_data(name, timestamp, environ=environ)
#     533 return BundleData(
#     534     asset_finder=AssetFinder(
#     535         asset_db_path(name, timestr, environ=environ),
#    (...)
#     545     ),
#     546 )
#
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\zipline\data\bundles\core.py:504, in _make_bundle_core.<locals>.most_recent_data(bundle_name, timestamp, environ)
#     502 if getattr(e, "errno", errno.ENOENT) != errno.ENOENT:
#     503     raise
# --> 504 raise ValueError(
#     505     "no data for bundle {bundle!r} on or before {timestamp}\n"
#     506     "maybe you need to run: $ zipline ingest -b {bundle}".format(
#     507         bundle=bundle_name,
#     508         timestamp=timestamp,
#     509     ),
#     510 )
#
# ValueError: no data for bundle 'quandl' on or before 2023-08-07 05:20:19.513208+00:00
# maybe you need to run: $ zipline ingest -b quandl

# %% [markdown]
# We can plot the data as follows:

# %%
df = pd.read_csv('stock_data.csv')
df.date = pd.to_datetime(df.date)
df.set_index('date').groupby('asset').price.plot(lw=2, legend=True, figsize=(14, 6))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df = pd.read_csv('stock_data.csv')
#       2 df.date = pd.to_datetime(df.date)
#       3 df.set_index('date').groupby('asset').price.plot(lw=2, legend=True, figsize=(14, 6))
#
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'stock_data.csv'

# %% [markdown]
# ### Simple moving average strategy

# %% [markdown]
# The following code example illustrates a [Dual Moving Average Cross-Over Strategy](https://zipline.ml4trading.io/beginner-tutorial.html#access-to-previous-prices-using-history) to demonstrate Zipline in action:

# %%
# %%zipline --start 2014-1-1 --end 2018-1-1 --no-benchmark -o dma.pickle
# from zipline.api import order_target, record, symbol
# import matplotlib.pyplot as plt
#
# def initialize(context):
#     context.i = 0
#     context.asset = symbol('AAPL')
#
#
# def handle_data(context, data):
#     # Skip first 300 days to get full windows
#     context.i += 1
#     if context.i < 300:
#         return
#
#     # Compute averages
#     # data.history() has to be called with the same params
#     # from above and returns a pandas dataframe.
#     short_mavg = data.history(context.asset, 'price', bar_count=100, frequency="1d").mean()
#     long_mavg = data.history(context.asset, 'price', bar_count=300, frequency="1d").mean()
#
#     # Trading logic
#     if short_mavg > long_mavg:
#         # order_target orders as many shares as needed to
#         # achieve the desired number of shares.
#         order_target(context.asset, 100)
#     elif short_mavg < long_mavg:
#         order_target(context.asset, 0)
#
#     # Save values for later inspection
#     record(AAPL=data.current(context.asset, 'price'),
#            short_mavg=short_mavg,
#            long_mavg=long_mavg)
#
#
# def analyze(context, perf):
#     fig, (ax1, ax2) = plt.subplots(nrows=2,figsize=(14, 8))
#     perf.portfolio_value.plot(ax=ax1)
#     ax1.set_ylabel('portfolio value in $')
#
#     perf['AAPL'].plot(ax=ax2)
#     perf[['short_mavg', 'long_mavg']].plot(ax=ax2)
#
#     perf_trans = perf.loc[[t != [] for t in perf.transactions]]
#     buys = perf_trans.loc[[t[0]['amount'] > 0 for t in perf_trans.transactions]]
#     sells = perf_trans.loc[
#         [t[0]['amount'] < 0 for t in perf_trans.transactions]]
#     ax2.plot(buys.index, perf.short_mavg.loc[buys.index],
#              '^', markersize=10, color='m')
#     ax2.plot(sells.index, perf.short_mavg.loc[sells.index],
#              'v', markersize=10, color='k')
#     ax2.set_ylabel('price in $')
#     plt.legend(loc=0)
#     plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\zipline\data\bundles\core.py:488, in _make_bundle_core.<locals>.most_recent_data(bundle_name, timestamp, environ)
#     487 try:
# --> 488     candidates = os.listdir(
#     489         pth.data_path([bundle_name], environ=environ),
#     490     )
#     491     return pth.data_path(
#     492         [
#     493             bundle_name,
#    (...)
#     499         environ=environ,
#     500     )
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\kikim\\.zipline\\data\\quandl'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 get_ipython().run_cell_magic('zipline', '--start 2014-1-1 --end 2018-1-1 --no-benchmark -o dma.pickle', 'from zipline.api import order_target, record, symbol\nimport matplotlib.pyplot as plt\n\ndef initialize(context):\n    context.i = 0\n    context.asset = symbol(\'AAPL\')\n\n\ndef handle_data(context, data):\n    # Skip first 300 days to get full windows\n    context.i += 1\n    if context.i < 300:\n        return\n\n    # Compute averages\n    # data.history() has to be called with the same params\n    # from above and returns a pandas dataframe.\n    short_mavg = data.history(context.asset, \'price\', bar_count=100, frequency="1d").mean()\n    long_mavg = data.history(context.asset, \'price\', bar_count=300, frequency="1d").mean()\n\n    # Trading logic\n    if short_mavg > long_mavg:\n        # order_target orders as many shares as needed to\n        # achieve the desired number of shares.\n        order_target(context.asset, 100)\n    elif short_mavg < long_mavg:\n        order_target(context.asset, 0)\n\n    # Save values for later inspection\n    record(AAPL=data.current(context.asset, \'price\'),\n           short_mavg=short_mavg,\n           long_mavg=long_mavg)\n\n\ndef analyze(context, perf):\n    fig, (ax1, ax2) = plt.subplots(nrows=2,figsize=(14, 8))\n    perf.portfolio_value.plot(ax=ax1)\n    ax1.set_ylabel(\'portfolio value in $\')\n\n    perf[\'AAPL\'].plot(ax=ax2)\n    perf[[\'short_mavg\', \'long_mavg\']].plot(ax=ax2)\n\n    perf_trans = perf.loc[[t != [] for t in perf.transactions]]\n    buys = perf_trans.loc[[t[0][\'amount\'] > 0 for t in perf_trans.transactions]]\n    sells = perf_trans.loc[\n        [t[0][\'amount\'] < 0 for t in perf_trans.transactions]]\n    ax2.plot(buys.index, perf.short_mavg.loc[buys.index],\n             \'^\', markersize=10, color=\'m\')\n    ax2.plot(sells.index, perf.short_mavg.loc[sells.index],\n             \'v\', markersize=10, color=\'k\')\n    ax2.set_ylabel(\'price in $\')\n    plt.legend(loc=0)\n    plt.show() \n')
#
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\IPython\core\interactiveshell.py:2478, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2476 with self.builtin_trap:
#    2477     args = (magic_arg_s, cell)
# -> 2478     result = fn(*args, **kwargs)
#    2480 # The code below prevents the output from being displayed
#    2481 # when using magics with decodator @output_can_be_silenced
#    2482 # when the last Python token in the expression is a ';'.
#    2483 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\zipline\__main__.py:341, in zipline_magic(line, cell)
#     334 load_extensions(
#     335     default=True,
#     336     extensions=[],
#     337     strict=True,
#     338     environ=os.environ,
#     339 )
#     340 try:
# --> 341     return run.main(
#     342         # put our overrides at the start of the parameter list so that
#     343         # users may pass values with higher precedence
#     344         [
#     345             "--algotext",
#     346             cell,
#     347             "--output",
#     348             os.devnull,  # don't write the results by default
#     349         ]
#     350         + (
#     351             [
#     352                 # these options are set when running in line magic mode
#     353                 # set a non None algo text to use the ipython user_ns
#     354                 "--algotext",
#     355                 "",
#     356                 "--local-namespace",
#     357             ]
#     358             if cell is None
#     359             else []
#     360         )
#     361         + line.split(),
#     362         "%s%%zipline" % ((cell or "") and "%"),
#     363         # don't use system exit and propogate errors to the caller
#     364         standalone_mode=False,
#     365     )
#     366 except SystemExit as exc:
#     367     # https://github.com/mitsuhiko/click/pull/533
#     368     # even in standalone_mode=False `--help` really wants to kill us ;_;
#     369     if exc.code:
#
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\click\core.py:1078, in BaseCommand.main(self, args, prog_name, complete_var, standalone_mode, windows_expand_args, **extra)
#    1076 try:
#    1077     with self.make_context(prog_name, args, **extra) as ctx:
# -> 1078         rv = self.invoke(ctx)
#    1079         if not standalone_mode:
#    1080             return rv
#
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\click\core.py:1434, in Command.invoke(self, ctx)
#    1431     echo(style(message, fg="red"), err=True)
#    1433 if self.callback is not None:
# -> 1434     return ctx.invoke(self.callback, **ctx.params)
#
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\click\core.py:783, in Context.invoke(_Context__self, _Context__callback, *args, **kwargs)
#     781 with augment_usage_errors(__self):
#     782     with ctx:
# --> 783         return __callback(*args, **kwargs)
#
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\click\decorators.py:33, in pass_context.<locals>.new_func(*args, **kwargs)
#      32 def new_func(*args: "P.args", **kwargs: "P.kwargs") -> "R":
# ---> 33     return f(get_current_context(), *args, **kwargs)
#
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\zipline\__main__.py:306, in run(ctx, algofile, algotext, define, data_frequency, capital_base, bundle, bundle_timestamp, benchmark_file, benchmark_symbol, benchmark_sid, no_benchmark, start, end, output, trading_calendar, print_algo, metrics_set, local_namespace, blotter)
#     297 trading_calendar = get_calendar(trading_calendar)
#     299 benchmark_spec = BenchmarkSpec.from_cli_params(
#     300     no_benchmark=no_benchmark,
#     301     benchmark_sid=benchmark_sid,
#     302     benchmark_symbol=benchmark_symbol,
#     303     benchmark_file=benchmark_file,
#     304 )
# --> 306 return _run(
#     307     initialize=None,
#     308     handle_data=None,
#     309     before_trading_start=None,
#     310     analyze=None,
#     311     algofile=algofile,
#     312     algotext=algotext,
#     313     defines=define,
#     314     data_frequency=data_frequency,
#     315     capital_base=capital_base,
#     316     bundle=bundle,
#     317     bundle_timestamp=bundle_timestamp,
#     318     start=start,
#     319     end=end,
#     320     output=output,
#     321     trading_calendar=trading_calendar,
#     322     print_algo=print_algo,
#     323     metrics_set=metrics_set,
#     324     local_namespace=local_namespace,
#     325     environ=os.environ,
#     326     blotter=blotter,
#     327     benchmark_spec=benchmark_spec,
#     328     custom_loader=None,
#     329 )
#
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\zipline\utils\run_algo.py:93, in _run(handle_data, initialize, before_trading_start, analyze, algofile, algotext, defines, data_frequency, capital_base, bundle, bundle_timestamp, start, end, output, trading_calendar, print_algo, metrics_set, local_namespace, environ, blotter, custom_loader, benchmark_spec)
#      64 def _run(
#      65     handle_data,
#      66     initialize,
#    (...)
#      86     benchmark_spec,
#      87 ):
#      88     """Run a backtest for the given algorithm.
#      89
#      90     This is shared between the cli and :func:`zipline.run_algo`.
#      91     """
# ---> 93     bundle_data = bundles.load(
#      94         bundle,
#      95         environ,
#      96         bundle_timestamp,
#      97     )
#      99     if trading_calendar is None:
#     100         trading_calendar = get_calendar("XNYS")
#
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\zipline\data\bundles\core.py:532, in _make_bundle_core.<locals>.load(name, environ, timestamp)
#     530 if timestamp is None:
#     531     timestamp = pd.Timestamp.utcnow()
# --> 532 timestr = most_recent_data(name, timestamp, environ=environ)
#     533 return BundleData(
#     534     asset_finder=AssetFinder(
#     535         asset_db_path(name, timestr, environ=environ),
#    (...)
#     545     ),
#     546 )
#
# File ~\miniconda3\envs\machine-learning-for-trading\Lib\site-packages\zipline\data\bundles\core.py:504, in _make_bundle_core.<locals>.most_recent_data(bundle_name, timestamp, environ)
#     502 if getattr(e, "errno", errno.ENOENT) != errno.ENOENT:
#     503     raise
# --> 504 raise ValueError(
#     505     "no data for bundle {bundle!r} on or before {timestamp}\n"
#     506     "maybe you need to run: $ zipline ingest -b {bundle}".format(
#     507         bundle=bundle_name,
#     508         timestamp=timestamp,
#     509     ),
#     510 )
#
# ValueError: no data for bundle 'quandl' on or before 2023-08-07 05:20:19.513208+00:00
# maybe you need to run: $ zipline ingest -b quandl
